# %%
#importing Pandas
import pandas as pd

# %%
#reading Box Office Mojo database
bom_df = pd.read_csv("zippedData/bom.movie_gross.csv.gz", compression='gzip')

# %%
bom_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_df.head(20)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
bom_df.tail(20)
# Out:
#                                                   title      studio  \
# 3367                      Elliot: The Littlest Reindeer       Scre.
# 3368                                       The Workshop      Strand
# 3369                                       Loving Pablo        Uni.
# 3370                                  A Paris Education          KL
# 3371                          Tag Along: The Devil Fish          CL
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3377                                    Let Yourself Go        Men.
# 3378                                      Hannah (2018)         PDF
# 3379                                           Souvenir      Strand
# ...

# %%
bom_df.year.value_counts().sort_index()
# Out:
# 2010    328
# 2011    399
# 2012    400
# 2013    350
# 2014    395
# 2015    450
# 2016    436
# 2017    321
# 2018    308
# Name: year, dtype: int64

# %% [markdown]
# Have data for 2010-2018

# %%
bom_df.studio.value_counts().head(60)
# Out:
# IFC         166
# Uni.        147
# WB          140
# Magn.       136
# Fox         136
# SPC         123
# Sony        110
# BV          106
# LGF         103
# Par.        101
# Eros         89
# Wein.        77
# CL           74
# Strand       68
# FoxS         67
# RAtt.        66
# KL           62
# Focus        60
# WGUSA        58
# CJ           56
# MBox         54
# UTV          50
# A24          49
# WB (NL)      45
# FM           42
# LG/S         41
# Cohen        40
# ORF          37
# SGem         35
# Rela.        35
# FIP          26
# GK           24
# STX          24
# Gold.        24
# Osci.        23
# TriS         23
# RTWC         23
# MNE          22
# BST          22
# EOne         21
# Distrib.     20
# Drft.        20
# Relbig.      18
# Anch.        18
# CBS          17
# BG           16
# Zeit.        16
# Sum.         15
# FD           14
# Yash         14
# W/Dim.       14
# Trib.        14
# Orch.        13
# Free         12
# FCW          12
# ...

# %%
bom_df.studio.isna().sum()
# Out:
# 5

# %%
bom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_df.loc[bom_df.year==2018]
# Out:
#                                title      studio  domestic_gross  \
# 3079          Avengers: Infinity War          BV     678800000.0
# 3080                   Black Panther          BV     700100000.0
# 3081  Jurassic World: Fallen Kingdom        Uni.     417700000.0
# 3082                   Incredibles 2          BV     608600000.0
# 3083                         Aquaman          WB     335100000.0
# ...                              ...         ...             ...
# 3382                       The Quake       Magn.          6200.0
# 3383     Edward II (2018 re-release)          FM          4800.0
# 3384                        El Pacto        Sony          2500.0
# 3385                        The Swan  Synergetic          2400.0
# 3386               An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 3079       1,369.5  2018
# 3080     646900000  2018
# 3081     891800000  2018
# 3082     634200000  2018
# 3083     812700000  2018
# ...            ...   ...
# ...

# %%
bom_df.domestic_gross.isna().sum()
# Out:
# 28

# %%
bom_df.loc[bom_df.foreign_gross.isna() & bom_df.domestic_gross.isna()]
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year]
# Index: []

# %% [markdown]
# Box Office Mojo
#
# -All the rows have years and titles.
# -There are 5 missing studios--perhaps these are independent films? <br>
# -the studios might have different names for the same studio. need to fix. <br>
# -we have domestic and foreign gross.  could add together for total gross.<br>
# -both domestic and foreign have nulls-probably only marketed domestically or non-domestically. none have nulls for both. could impute 0

# %%
#read Rotten Tomatoes Movie Info
rt_mi_df = pd.read_csv("zippedData/rt.movie_info.tsv.gz", sep = '\t', compression = 'gzip')

# %%
rt_mi_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %% [markdown]
# The Rotten Tomatoes Movie Info DataFrame contains info for select movies, but not the titles, so probably need to merge with another dataframe.

# %%
rt_mi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %% [markdown]
# Very little box office ($) info.  Probably just use gross info from BOM dataframe.  Missing only 3 ratings, 8 genres, and 30 runtimes, so maybe just drop those rows.  Theater_date/dvd_date: we do have the years from the BOM at least.  Missing few hundred directors and writers, which could be problematic.  Have studios from BOM dataframe.

# %%
rt_mi_df.rating.value_counts()
# Out:
# R        521
# NR       503
# PG       240
# PG-13    235
# G         57
# NC17       1
# Name: rating, dtype: int64

# %% [markdown]
# Ratings (for nonnull at least) look good.

# %%
rt_mi_df.genre.value_counts().head(50).sort_index
# Out:
# <bound method Series.sort_index of Drama                                                      151
# Comedy                                                     110
# Comedy|Drama                                                80
# Drama|Mystery and Suspense                                  67
# Art House and International|Drama                           62
# Action and Adventure|Drama                                  42
# Action and Adventure|Drama|Mystery and Suspense             40
# Drama|Romance                                               35
# Comedy|Romance                                              32
# Horror                                                      31
# Art House and International|Comedy|Drama                    31
# Action and Adventure|Science Fiction and Fantasy            24
# Comedy|Drama|Romance                                        23
# Classics|Drama                                              21
# ...

# %% [markdown]
# OK this is ridiculous.  You have several different genres for the same movie, separated by "|".  Need to deal with this somehow.  Could create true-false Boolean columns like "is_drama", "is_comedy", etc

# %%
rt_mi_df[rt_mi_df.director.str.contains("|", regex=False, na=False)]
# Out:
#         id                                           synopsis rating  \
# 43      56  Albert Hughes and his brother Allen Hughes fol...      R
# 53      67  After a mysterious, lost night on their honeym...      R
# 100    128                                                NaN     NR
# 121    155  Taking place over the course of one night, The...      R
# 146    191  Award-winning filmmaker Rakeysh Omprakash Mehr...     NR
# ...    ...                                                ...    ...
# 1490  1918  A collection of 15 chapters from Tarzan and th...     NR
# 1511  1945  Left on a nun's doorstep, Larry, Curly and Moe...     PG
# 1518  1953  A glimpse into the comedic process and private...      R
# 1529  1966  Two rabid Boston B-ball fans go over the edge ...  PG-13
# 1544  1983  This animated children's film spoofs the Sherl...      G
#
#                                                genre  \
# 43                                             Drama
# ...

# %% [markdown]
# How to deal with multiple directors/writers?  Only 96 movies with mult directors...

# %%
rt_mi_df[rt_mi_df.writer.str.contains("|", regex=False, na=False)]
# Out:
#         id                                           synopsis rating  \
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 7       13  Stewart Kane, an Irishman living in the Austra...      R
# 13      20  Rachel (Britt Ekland) is an Amish girl who rej...  PG-13
# 14      21  Old-school comic Rodney "I get no respect" Dan...      R
# ...    ...                                                ...    ...
# 1550  1990  A hard-working Sicilian heads for Switzerland ...      R
# 1551  1991  Popular rap group Run DMC stars as a trio of p...      R
# 1552  1992  The title character, played by John Turturro, ...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
#
#                                                 genre            director  \
# ...

# %% [markdown]
# But there are 499 movies with multiple writers!

# %% [markdown]
# Let's look at the Rotten Tomatoes review table:

# %%
rt_rev_df = pd.read_csv("zippedData/rt.reviews.tsv.gz", compression = 'gzip', sep = '\t', encoding = 'unicode_escape')

# %%
rt_rev_df.head(20)
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1    3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2    3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3    3  Continuing along a line introduced in last yea...    NaN   fresh
# 4    3             ... a perverse twist on neorealism...     NaN   fresh
# 5    3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 8    3  Cronenberg's cold, exacting precision and emot...    NaN   fresh
# 9    3  Over and above its topical urgency or the bit ...    NaN   fresh
# 10   3  Cosmopolis" is a hypnotic examination of our m...    NaN   fresh
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# ...

# %% [markdown]
# Cool. So there are several reviews for each movie in the other RT df.  Can merge on id.

# %%
rt_rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
rt_rev_df[rt_rev_df.review.isna()]
# Out:
#          id review rating   fresh             critic  top_critic  \
# 162       3    NaN      B   fresh       Emanuel Levy           0
# 169       5    NaN    3/5   fresh       Cole Smithey           0
# 170       5    NaN    2/5  rotten      Chuck O'Leary           0
# 171       5    NaN    3/5   fresh      Philip Martin           0
# 172       5    NaN    3/5   fresh         Eric Melin           0
# ...     ...    ...    ...     ...                ...         ...
# 54393  1999    NaN    4/5   fresh     Scott Weinberg           0
# 54428  2000    NaN    1/5  rotten  Michael Szymanski           0
# 54429  2000    NaN    2/5  rotten       Emanuel Levy           0
# 54430  2000    NaN  2.5/5  rotten   Christopher Null           0
# 54431  2000    NaN    3/5   fresh    Nicolas Lacroix           0
#
#                        publisher                date
# 162              EmanuelLevy.Com   December 25, 2012
# 169              ColeSmithey.com    October 10, 2005
# ...

# %% [markdown]
# A lot of reviews are missing, but that's probably ok.  All of them have at least fresh or rotten.

# %%
rt_rev_df.rating.value_counts().head(50)
# Out:
# 3/5       4327
# 4/5       3672
# 3/4       3577
# 2/5       3160
# 2/4       2712
# 2.5/4     2381
# 3.5/4     1777
# 3.5/5     1289
# 5/5       1237
# B         1163
# 1/5       1113
# 1.5/4     1095
# 4/4        995
# 2.5/5      992
# B+         832
# 1/4        822
# B-         821
# C          779
# C+         665
# 4.5/5      567
# 7/10       522
# A-         514
# 8/10       505
# C-         493
# 6/10       468
# 1.5/5      405
# A          397
# 5/10       351
# D          324
# 9/10       304
# 4/10       252
# D+         204
# 0/5        162
# 8          143
# 3/10       140
# 1          138
# 0/4        132
# 7          125
# F          109
# 0.5/4      100
# D-          84
# 6           82
# 2/10        73
# A+          73
# 7.5/10      58
# 0.5/5       52
# 5           48
# 8.5/10      41
# 6.5/10      39
# 4           34
# Name: rating, dtype: int64

# %% [markdown]
# The rating system is a little all over.  Need to make consistent.  Most are out of 5.  Some are out of 10.  Some are letter-graded.  Shouldn't be too too hard to fix, just .replace.

# %%
rt_rev_df.fresh.value_counts()
# Out:
# fresh     33035
# rotten    21397
# Name: fresh, dtype: int64

# %% [markdown]
# Perfect.  So can calculate a fresh percentage for each movie.

# %%
rt_rev_df.top_critic.value_counts()
# Out:
# 0    41336
# 1    13096
# Name: top_critic, dtype: int64

# %% [markdown]
# What is top critic and do I care?  Maybe just look at top critics to get review data from more reputable sources.

# %% [markdown]
# Also, there seems to be no way to tell what movies these are.  Can use to try to distinguish which genres, writers, directors have high rated movies and fresh movies.

# %% [markdown]
# Now reading database from The Movie DB

# %%
tmdb_df = pd.read_csv("zippedData/tmdb.movies.csv.gz", compression = 'gzip', index_col=0)

# %%
tmdb_df.head(20)
# Out:
#                    genre_ids     id original_language  \
# 0            [12, 14, 10751]  12444                en
# 1        [14, 12, 16, 10751]  10191                en
# 2              [12, 28, 878]  10138                en
# 3            [16, 35, 10751]    862                en
# 4              [28, 878, 12]  27205                en
# 5            [12, 14, 10751]  32657                en
# 6          [28, 12, 14, 878]  19995                en
# 7            [16, 10751, 35]  10193                en
# 8            [16, 10751, 35]  20352                en
# 9   [16, 28, 35, 10751, 878]  38055                en
# 10           [16, 35, 10751]    863                en
# 11           [10751, 14, 12]  12155                en
# 12              [53, 12, 28]  27578                en
# 13               [16, 10751]  38757                en
# 14                  [27, 80]  41439                en
# 15       [12, 14, 18, 10749]  24021                en
# ...

# %% [markdown]
# movies appear to have a user score out of 10.  We also have info on how many users voted.  Not sure what popularity means exactly.  No idea what to do with these genre ids.  Would be nice to have the genre ids key so I can look at which genres have higher ratings.  Basically just have titles and votes at this point.  hmm.

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# No nulls?!?!?!?

# %% [markdown]
# Let's look at "The Numbers" data

# %%
tn_df = pd.read_csv("zippedData/tn.movie_budgets.csv.gz", compression= 'gzip')

# %%
tn_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# So we have each movie, its production budget, and gross (domestic and worldwide).  Gross will probably be most useful.  Insights regarding whether investing outside the US might be interesting, but generally let's get info about which genres, writers, directors have the highest gross.

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# hooray!!! no nulls!

# %% [markdown]
# ### SQL shizz

# %% [markdown]
# Let's import SQLite and establish a connection

# %%
import sqlite3

conn = sqlite3.Connection("im.db")

# %%
pd.read_sql("""
    SELECT *
    FROM persons

""",conn)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
pd.read_sql("""
    SELECT *
    FROM writers

""",conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %% [markdown]
# Cool, so can merge with persons on person_id to get person info, and use movie_id to get movie info, and eventually gross info.

# %%
pd.read_sql("""
    SELECT *
    FROM directors
""",conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %% [markdown]
# similar

# %%
pd.read_sql("""
    SELECT *
    FROM known_for
""",conn)
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %% [markdown]
# Not sure what to make of this.

# %%
pd.read_sql("""
    SELECT *
    FROM principals
""",conn)
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# ...

# %% [markdown]
# Not sure how useful this is.

# %%
pd.read_sql("""
    SELECT *
    FROM movie_basics
""",conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# So we have movie_ids--can grab writers, directors.  But also have titles.  Can use with gross info (bom or tn) as well as ratings info (hooray, i can actually use the ratings from tmdb).

# %%
pd.read_sql("""
    SELECT *
    FROM movie_ratings
""",conn)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# Also have movie ratings here.

# %%
pd.read_sql("""
    SELECT *
    FROM movie_akas
""",conn)
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %% [markdown]
# Might not need this.
