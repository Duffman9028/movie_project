# %% [markdown]
# ## CLEANING ROTTEN TOMATOES REVIEWS/INFO DATASETS ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
reviews_data = pd.read_csv("/Users/julieleung/Desktop/dsc-phase-1-project-template/zippedData/rt.reviews.tsv.gz", 
                           compression="gzip", sep="\t", encoding="unicode_escape")
reviews_data
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
movie_info_data = pd.read_csv("/Users/julieleung/Desktop/dsc-phase-1-project-template/zippedData/rt.movie_info.tsv.gz", 
                              compression="gzip", sep="\t", encoding="unicode_escape")
movie_info_data
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
reviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
reviews_data['fresh'].value_counts()
# Out:
# fresh
# fresh     33035
# rotten    21397
# Name: count, dtype: int64

# %%
reviews_data['id'].value_counts()
# Out:
# id
# 782     338
# 1067    275
# 1525    262
# 1777    260
# 1083    260
#        ...
# 1393      1
# 411       1
# 770       1
# 1125      1
# 1526      1
# Name: count, Length: 1135, dtype: int64

# %%
reviews_data['top_critic'].value_counts()
# Out:
# top_critic
# 0    41336
# 1    13096
# Name: count, dtype: int64

# %%
reviews_data["publisher"].value_counts()
# Out:
# publisher
# eFilmCritic.com          673
# EmanuelLevy.Com          591
# New York Times           590
# Washington Post          565
# Entertainment Weekly     541
#                         ...
# El Fanzine                 1
# People's World             1
# New York Theatre Wire      1
# Out of the Past            1
# OZY                        1
# Name: count, Length: 1281, dtype: int64

# %%
reviews_data[["id", "review", "rating", "fresh", "critic", "top_critic", "publisher"]].sort_values(["id"], ascending=False)
# Out:
#          id                                             review rating   fresh  \
# 54431  2000                                                NaN    3/5   fresh
# 54403  2000  Reno does what he can in a thankless situation...  1.5/4  rotten
# 54410  2000  A silly, cross-cultural shoot-'em-up -- the so...    2/4   fresh
# 54409  2000  A lightweight, uneven action comedy that freel...    NaN  rotten
# 54408  2000  May lack the pungent bite of its title, but it...     C+   fresh
# ...     ...                                                ...    ...     ...
# 109       3  Hard to endure due to its pretentious nature, ...  1.5/5  rotten
# 108       3  A sensual, propulsive thriller, the apocalypse...    4/5   fresh
# 107       3  [VIDEO ESSAY] If intellectual sarcasm is your ...     C-   fresh
# 106       3  Diamond-hard and dazzlingly brilliant, David C...  3.5/4   fresh
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
#
# ...

# %%
reviews_data["rating"].unique()
# Out:
# array(['3/5', nan, 'C', '2/5', 'B-', '2/4', 'B', '3/4', '4/5', '4/4',
#        '6/10', '1/4', '8', '2.5/4', '4/10', '2.0/5', '3/10', '7/10', 'A-',
#        '5/5', 'F', '3.5/4', 'D+', '1.5/4', '3.5/5', '8/10', 'B+', '9/10',
#        '2.5/5', '7.5/10', '5.5/10', 'C-', '1.5/5', '1/5', '5/10', 'C+',
#        '0/5', '6', '0.5/4', 'D', '3.1/5', '3/6', '4.5/5', '0/4', '2/10',
#        'D-', '7', '1/10', '3', 'A+', 'A', '4.0/4', '9.5/10', '2.5',
#        '2.1/2', '6.5/10', '3.7/5', '8.4/10', '9', '1', '7.2/10', '2.2/5',
#        '0.5/10', '5', '0', '2', '4.5', '7.7', '5.0/5', '8.5/10', '3.0/5',
#        '0.5/5', '1.5/10', '3.0/4', '2.3/10', '4.5/10', '4/6', '3.5',
#        '8.6/10', '6/8', '2.0/4', '2.7', '4.2/10', '5.8', '4', '7.1/10',
#        '5/4', 'N', '3.5/10', '5.8/10', 'R', '4.0/5', '0/10', '5.0/10',
#        '5.9/10', '2.4/5', '1.9/5', '4.9', '7.4/10', '1.5', '2.3/4',
#        '8.8/10', '4.0/10', '2.2', '3.8/10', '6.8/10', '7.3', '7.0/10',
# ...

# %%
reviews_data["rating"] = reviews_data["rating"].replace({'A+':'15/15',
                                                 'A':'14/15',
                                                 'A-':'13/15',
                                                 'B+':'12/15',
                                                 'B':'11/15',
                                                 'B-':'10/15',
                                                 'C+':'9/15',
                                                 'C':'8/15',
                                                 'C-':'7/15',
                                                 'D+':'6/15',
                                                 'D':'5/15',
                                                 'D-':'4/15',
                                                 'F+':'3/15',
                                                 'F':'2/15',
                                                 'F-':'1/15'})

# %%
reviews_data['rating'].value_counts().head()
# Out:
# rating
# 3/5    4327
# 4/5    3672
# 3/4    3577
# 2/5    3160
# 2/4    2712
# Name: count, dtype: int64

# %%
import string 
letters = string.ascii_uppercase

def to_decimal(fraction):
    if isinstance(fraction, str):
        try:
            a, b = fraction.split('/')
            x  = round((float(a) / float(b)), 2)
            return x
        except ValueError:
            return fraction
    else:
        return fraction
    
reviews_data['rating'] = reviews_data['rating'].map(lambda x: to_decimal(x) if x is not letters else x )
reviews_data['rating']
# Out:
# 0        0.6
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 54427    NaN
# 54428    0.2
# 54429    0.4
# 54430    0.5
# 54431    0.6
# Name: rating, Length: 54432, dtype: object

# %%
reviews_data['rating'].unique()
# Out:
# array([0.6, nan, 0.53, 0.4, 0.67, 0.5, 0.73, 0.75, 0.8, 1.0, 0.25, '8',
#        0.62, 0.3, 0.7, 0.87, 0.13, 0.88, 0.38, 0.9, 0.55, 0.47, 0.2, 0.0,
#        '6', 0.12, 0.33, 0.27, '7', 0.1, '3', 0.93, 0.95, '2.5', 1.05,
#        0.65, 0.74, 0.84, '9', '1', 0.72, 0.44, 0.05, '5', '0', '2', '4.5',
#        '7.7', 0.85, 0.15, 0.23, 0.45, '3.5', 0.86, '2.7', 0.42, '5.8',
#        '4', 0.71, 1.25, 'N', 0.35, 0.58, 'R', 0.59, 0.48, '4.9', '1.5',
#        0.57, '2.2', 0.68, '7.3', '3.2', '4.2', '8.4', 1.1, 0.63, 0.76,
#        0.81, 0.77, '1.8', 0.89, '8.9', 0.82, 0.83, 0.43, 0.41, 0.79, 0.96,
#        '4.0', '1.7', '7.9', '6.7', 0.92, '5.2', '5.9', '3.7', '4.7', 0.17,
#        '8.2', 0.52, '3.4', '9.7', 0.66, '7.4', '4.8', 0.32, '1-5', '1.0',
#        '9.2', 0.54, 0.49, '3.0', '3.1', 0.78, 0.07, 0.46, 1.5, '7.8',
#        '9.0', 0.69, 'T', '6.2', '3.3', '9.8', '8.5', '4.1', '7.1',
#        '3 1/2'], dtype=object)

# %%
reviews_data['rating'].value_counts().head()
# Out:
# rating
# 0.6     5478
# 0.8     5020
# 0.5     4079
# 0.75    3664
# 0.4     3629
# Name: count, dtype: int64

# %%
reviews_data.dropna(subset=['rating'], inplace=True)

# %%
reviews_data['rating'].unique()
# Out:
# array([0.6, 0.53, 0.4, 0.67, 0.5, 0.73, 0.75, 0.8, 1.0, 0.25, '8', 0.62,
#        0.3, 0.7, 0.87, 0.13, 0.88, 0.38, 0.9, 0.55, 0.47, 0.2, 0.0, '6',
#        0.12, 0.33, 0.27, '7', 0.1, '3', 0.93, 0.95, '2.5', 1.05, 0.65,
#        0.74, 0.84, '9', '1', 0.72, 0.44, 0.05, '5', '0', '2', '4.5',
#        '7.7', 0.85, 0.15, 0.23, 0.45, '3.5', 0.86, '2.7', 0.42, '5.8',
#        '4', 0.71, 1.25, 'N', 0.35, 0.58, 'R', 0.59, 0.48, '4.9', '1.5',
#        0.57, '2.2', 0.68, '7.3', '3.2', '4.2', '8.4', 1.1, 0.63, 0.76,
#        0.81, 0.77, '1.8', 0.89, '8.9', 0.82, 0.83, 0.43, 0.41, 0.79, 0.96,
#        '4.0', '1.7', '7.9', '6.7', 0.92, '5.2', '5.9', '3.7', '4.7', 0.17,
#        '8.2', 0.52, '3.4', '9.7', 0.66, '7.4', '4.8', 0.32, '1-5', '1.0',
#        '9.2', 0.54, 0.49, '3.0', '3.1', 0.78, 0.07, 0.46, 1.5, '7.8',
#        '9.0', 0.69, 'T', '6.2', '3.3', '9.8', '8.5', '4.1', '7.1',
#        '3 1/2'], dtype=object)

# %%
reviews_data.reset_index()
# Out:
#        index    id                                             review rating  \
# 0          0     3  A distinctly gallows take on contemporary fina...    0.6
# 1          6     3  Quickly grows repetitive and tiresome, meander...   0.53
# 2          7     3  Cronenberg is not a director to be daunted by ...    0.4
# 3         11     3  While not one of Cronenberg's stronger films, ...   0.67
# 4         12     3  Robert Pattinson works mighty hard to make Cos...    0.5
# ...      ...   ...                                                ...    ...
# 40910  54424  2000  Dawdles and drags when it should pop; it doesn...    0.3
# 40911  54428  2000                                                NaN    0.2
# 40912  54429  2000                                                NaN    0.4
# 40913  54430  2000                                                NaN    0.5
# 40914  54431  2000                                                NaN    0.6
#
# ...

# %%
# reviews_data[reviews_data['id'] == 1999]

# %%
reviews_data['review'][7]
# Out:
# 'Cronenberg is not a director to be daunted by a scenario in which the antihero spends most of his time in a stretch limo. Turning it into a film that interests anyone ... is another matter'

# %%
#merging the two datasets together
merge_data = movie_info_data.merge(reviews_data, how="inner", on="id")

# %%
#renaming the two rating columns 
merge_data = merge_data.rename(columns={'rating_x':'movie_rating', 'rating_y':'review_rating'})

# %%
merge_data
# Out:
#          id                                           synopsis movie_rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...            R
# 1         3  New York City, not-too-distant-future: Eric Pa...            R
# 2         3  New York City, not-too-distant-future: Eric Pa...            R
# 3         3  New York City, not-too-distant-future: Eric Pa...            R
# 4         3  New York City, not-too-distant-future: Eric Pa...            R
# ...     ...                                                ...          ...
# 40824  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40825  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40826  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40827  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40828  1996  Forget terrorists or hijackers -- there's a ha...            R
#
# ...

# %%
merge_data.dtypes
# Out:
# id                int64
# synopsis         object
# movie_rating     object
# genre            object
# director         object
# writer           object
# theater_date     object
# dvd_date         object
# currency         object
# box_office       object
# runtime          object
# studio           object
# review           object
# review_rating    object
# fresh            object
# critic           object
# top_critic        int64
# publisher        object
# date             object
# dtype: object

# %%
merge_data['review_rating']
# Out:
# 0         0.6
# 1        0.53
# 2         0.4
# 3        0.67
# 4         0.5
#          ...
# 40910     0.3
# 40911     0.2
# 40912     0.4
# 40913     0.5
# 40914     0.6
# Name: review_rating, Length: 40915, dtype: object

# %%
#dropping these miscellaneous values 
merge_data = merge_data[merge_data['review_rating'] != 'T']
merge_data = merge_data[merge_data['review_rating'] != '1-5']
merge_data = merge_data[merge_data['review_rating'] != 'R']
merge_data = merge_data[merge_data['review_rating'] != 'N']
merge_data = merge_data[merge_data['review_rating'] != '3 1/2']

# %%
#only having numeric values 
merge_data['review_rating'] = pd.to_numeric(merge_data['review_rating'])

# %%
merge_data['review_rating'].unique()
# Out:
# array([0.6 , 0.53, 0.4 , 0.67, 0.5 , 0.73, 0.75, 0.8 , 1.  , 0.25, 8.  ,
#        0.62, 0.3 , 0.7 , 0.87, 0.13, 0.88, 0.38, 0.9 , 0.55, 0.47, 0.2 ,
#        0.  , 6.  , 0.12, 0.33, 0.27, 7.  , 0.1 , 3.  , 0.93, 0.95, 2.5 ,
#        1.05, 0.65, 0.74, 0.84, 9.  , 0.72, 0.44, 0.05, 5.  , 2.  , 4.5 ,
#        7.7 , 0.85, 0.15, 0.23, 0.45, 3.5 , 0.86, 2.7 , 0.42, 5.8 , 4.  ,
#        0.71, 1.25, 0.35, 0.58, 0.59, 0.48, 4.9 , 1.5 , 0.57, 2.2 , 0.68,
#        7.3 , 3.2 , 4.2 , 8.4 , 1.1 , 0.63, 0.76, 0.81, 0.77, 1.8 , 0.89,
#        8.9 , 0.82, 0.83, 0.43, 0.41, 0.79, 0.96, 1.7 , 7.9 , 6.7 , 0.92,
#        5.2 , 5.9 , 3.7 , 4.7 , 0.17, 8.2 , 0.52, 3.4 , 9.7 , 0.66, 7.4 ,
#        4.8 , 0.32, 9.2 , 0.54, 0.49, 3.1 , 0.78, 0.07, 0.46, 7.8 , 0.69,
#        6.2 , 3.3 , 9.8 , 8.5 , 4.1 , 7.1 ])

# %%
# reviews_data["rating"] = reviews_data["rating"].replace({'3 1/2' : '3.5'})

# %%
merge_data['review_rating'].value_counts().head()
# Out:
# review_rating
# 0.60    5478
# 0.80    5020
# 0.50    4079
# 0.75    3664
# 0.40    3629
# Name: count, dtype: int64

# %%
merge_data['review_rating'].value_counts().tail()
# Out:
# review_rating
# 7.30    1
# 0.57    1
# 4.90    1
# 0.52    1
# 7.10    1
# Name: count, dtype: int64

# %%
#Assume the values greater than 1 are out of 10

def out_of_ten(ele):
    if ele > 1:
        return round(ele/10, 2)
    else:
        return ele
merge_data['review_rating'] = merge_data['review_rating'].map(out_of_ten)

# %%
merge_data['review_rating'].unique()
# Out:
# array([0.6 , 0.53, 0.4 , 0.67, 0.5 , 0.73, 0.75, 0.8 , 1.  , 0.25, 0.62,
#        0.3 , 0.7 , 0.87, 0.13, 0.88, 0.38, 0.9 , 0.55, 0.47, 0.2 , 0.  ,
#        0.12, 0.33, 0.27, 0.1 , 0.93, 0.95, 0.11, 0.65, 0.74, 0.84, 0.72,
#        0.44, 0.05, 0.45, 0.77, 0.85, 0.15, 0.23, 0.35, 0.86, 0.42, 0.58,
#        0.71, 0.59, 0.48, 0.49, 0.57, 0.22, 0.68, 0.32, 0.63, 0.76, 0.81,
#        0.18, 0.89, 0.82, 0.83, 0.43, 0.41, 0.79, 0.96, 0.17, 0.92, 0.52,
#        0.37, 0.34, 0.97, 0.66, 0.54, 0.31, 0.78, 0.07, 0.46, 0.69, 0.98])

# %%
merge_data.describe()
# Out:
#                  id  review_rating    top_critic
# count  40905.000000   40905.000000  40905.000000
# mean    1043.119863       0.628463      0.196944
# std      587.160943       0.211347      0.397695
# min        3.000000       0.000000      0.000000
# 25%      542.000000       0.500000      0.000000
# 50%     1083.000000       0.620000      0.000000
# 75%     1541.000000       0.800000      0.000000
# max     2000.000000       1.000000      1.000000

# %%
plt.hist(merge_data['review_rating'], bins=20)
plt.show()

# %%
sns.boxplot(x=merge_data['review_rating']);

# %%
merge_data['fresh'].value_counts()
# Out:
# fresh
# fresh     24855
# rotten    16050
# Name: count, dtype: int64

# %%
x = (24855/40905)
y = (16050/40905)
print(x, y)
# Out:
# 0.6076274294096077 0.3923725705903924

# %%
#condensing all the name variations of studios into one 
merge_data['studio'] = merge_data['studio'].replace({'Sony Pictures Classics' : 'Sony Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'Sony Pictures Entertainment' : 'Sony Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'Sony Pictures Home Entertainment' : 'Sony Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Warner Bros.' : 'Warner Bros. Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'WARNER BROTHERS PICTURES' : 'Warner Bros. Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'WB' : 'Warner Bros. Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Twentieth Century Fox Home Entertainment' : '20th Century Fox'})
merge_data['studio'] = merge_data['studio'].replace({'Fox' : '20th Century Fox'})
merge_data['studio'] = merge_data['studio'].replace({'Fox Searchlight' : '20th Century Fox'})
merge_data['studio'] = merge_data['studio'].replace({'Fox Searchlight Pictures' : '20th Century Fox'})
merge_data['studio'] = merge_data['studio'].replace({'20th Century Fox Film Corporat' : '20th Century Fox'})
merge_data['studio'] = merge_data['studio'].replace({'20th Century Fox Distribution' : '20th Century Fox'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Paramount Studios' : 'Paramount Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'Paramount Home Video' : 'Paramount Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'Paramount' : 'Paramount Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Lions Gate Films' : 'Lionsgate Films'})
merge_data['studio'] = merge_data['studio'].replace({'Lions Gate Films Inc.' : 'Lionsgate Films'})
merge_data['studio'] = merge_data['studio'].replace({'Lions Gate Films Inc.' : 'Lionsgate Films'})
merge_data['studio'] = merge_data['studio'].replace({'Lionsgate' : 'Lionsgate Films'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Buena Vista Distribution Compa' : 'Buena Vista Pictures'})
merge_data['studio'] = merge_data['studio'].replace({'Buena Vista' : 'Buena Vista Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'A24' : 'A24 Films'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Universal Studios' : 'Universal Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'Walt Disney Animation Studios' : 'Walt Disney Pictures'})

# %%
merge_data['studio'] = merge_data['studio'].replace({'DreamWorks SKG' : 'Dreamworks Pictures'})

# %%
merge_data = merge_data[merge_data['studio'] != ' nan']

# %%
# dropping the null values in the studio column of the merge dataset
merge_data.dropna(subset=['studio'], inplace=True)

# %%
merge_data['studio'].unique()
# Out:
# array(['Entertainment One', 'Warner Bros. Pictures', 'Paramount Pictures',
#        'Sony Pictures', 'Seventh Art Releasing', 'Universal Pictures',
#        'MGM', 'Lionsgate Films', 'Regent Releasing', 'Janus Films',
#        'The Weinstein Company', 'New Line Cinema', 'Walt Disney Pictures',
#        '20th Century Fox', 'Newmarket Film Group', 'Samuel Goldwyn Films',
#        'Open Road Films', 'Roadside Attractions', 'Buena Vista Pictures',
#        'Dreamworks Pictures', 'New Yorker Films', 'Destination Films',
#        'Miramax', 'Columbia Pictures', 'Film District',
#        'Reliance Entertainment', 'Fine Line Features',
#        'Summit Entertainment', 'Dreamworks Distribution LLC',
#        'Focus Features', 'Laemmle/Zeller Films', 'Magnolia Pictures',
#        'Wrekin Hill Entertainment', 'Independant Pictures',
#        'Weinstein Company', 'Sony Pictures/TriStar Pictures',
#        'Criterion Collection', 'USA Films', 'Phase 4 Films',
# ...

# %%
merge_data
# Out:
#          id                                           synopsis movie_rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...            R
# 1         3  New York City, not-too-distant-future: Eric Pa...            R
# 2         3  New York City, not-too-distant-future: Eric Pa...            R
# 3         3  New York City, not-too-distant-future: Eric Pa...            R
# 4         3  New York City, not-too-distant-future: Eric Pa...            R
# ...     ...                                                ...          ...
# 40824  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40825  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40826  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40827  1996  Forget terrorists or hijackers -- there's a ha...            R
# 40828  1996  Forget terrorists or hijackers -- there's a ha...            R
#
# ...

# %%
sns.histplot(data = merge_data, x=merge_data["movie_rating"], stat="density", discrete=True);

# %%
merge_data['movie_rating'].value_counts()
# Out:
# movie_rating
# R        13198
# PG-13    11423
# PG        4481
# NR         566
# G          365
# Name: count, dtype: int64

# %%
import math
r = 13198
pg13 = 11423
pg = 4481
nr = 566
g = 365
x = r + pg13 + pg + nr + g

# %%
merge_data['box_office'].value_counts()
# Out:
# box_office
# 52,000,189     220
# 299,300,000    194
# 44,667,095     190
# 303,001,229    190
# 74,223,625     188
#               ...
# 1,626,289        6
# 1,231,550        5
# 8,300            4
# 1,416,189        3
# 586,242          2
# Name: count, Length: 265, dtype: int64

# %%
merge_data.dtypes
# Out:
# id                 int64
# synopsis          object
# movie_rating      object
# genre             object
# director          object
# writer            object
# theater_date      object
# dvd_date          object
# currency          object
# box_office        object
# runtime           object
# studio            object
# review            object
# review_rating    float64
# fresh             object
# critic            object
# top_critic         int64
# publisher         object
# date              object
# dtype: object

# %%
merge_data.dropna(subset=['box_office'], inplace=True)

# %%
merge_data['box_office'] = merge_data['box_office'].replace({',': ''}, regex=True)

# %%
merge_data['box_office'].value_counts().head(20)
# Out:
# box_office
# 52000189     220
# 299300000    194
# 44667095     190
# 303001229    190
# 74223625     188
# 20900803     186
# 368000000    185
# 99165609     181
# 127490802    177
# 44566004     170
# 600000       167
# 8518148      167
# 32741596     166
# 102515793    165
# 234141872    164
# 6002708      163
# 11348612     163
# 27696504     162
# 227946274    158
# 148734225    156
# Name: count, dtype: int64

# %%
merge_data['box_office']
# Out:
# 0          600000
# 1          600000
# 2          600000
# 3          600000
# 4          600000
#            ...
# 40824    33886034
# 40825    33886034
# 40826    33886034
# 40827    33886034
# 40828    33886034
# Name: box_office, Length: 23799, dtype: object

# %%
sns.histplot(data = merge_data, x=merge_data["box_office"], stat="density", bins=20);

# %%
merge_data['box_office'] = pd.to_numeric(merge_data['box_office'])

# %%
merge_data.corr(numeric_only=True)
# Out:
#                      id  box_office  review_rating  top_critic
# id             1.000000    0.070260       0.064256   -0.002393
# box_office     0.070260    1.000000       0.075446   -0.052171
# review_rating  0.064256    0.075446       1.000000   -0.013886
# top_critic    -0.002393   -0.052171      -0.013886    1.000000

# %%
unique_data = merge_data.drop_duplicates(subset=['id'])
unique_data
# Out:
#          id                                           synopsis movie_rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...            R
# 214      10  Some cast and crew from NBC's highly acclaimed...        PG-13
# 275      13  Stewart Kane, an Irishman living in the Austra...            R
# 509      23  A fictional film set in the alluring world of ...            R
# 696      25  From ancient Japan's most enduring tale, the e...        PG-13
# ...     ...                                                ...          ...
# 40102  1968  This holiday season, acclaimed filmmaker Camer...           PG
# 40273  1976  Embrace of the Serpent features the encounter,...           NR
# 40371  1980  A band of renegades on the run in outer space ...        PG-13
# 40502  1981  Money, Fame and the Knowledge of English. In I...           NR
# 40714  1996  Forget terrorists or hijackers -- there's a ha...            R
#
# ...

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=merge_data, x='review_rating', 
                y='box_office', hue='movie_rating').set_title("Correlation between Box Office and Review Ratings ")
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0)
# plt.savefig("scatter_box_review_movie.png")
;
# Out:
# ''

# %%
sns.boxplot(data=merge_data, x=merge_data["movie_rating"], y=merge_data["box_office"])
# plt.savefig("scatter_box_review_movie.png")
;
# Out:
# ''

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=unique_data, x='review_rating', 
                y='box_office', hue='movie_rating').set_title("Correlation between Box Office and Review Ratings ")
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0)
#plt.savefig("scatter_box_review_movie.png")
;
# Out:
# ''

# %%
#statistical summary of box office revenue on movie rating
df = unique_data.groupby(['movie_rating'])['box_office'].agg([np.mean, np.median, np.max, np.min, np.sum])
df = df.sort_values(by="mean", ascending=False)
df
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4796/2195697296.py:2: FutureWarning: The provided callable <function mean at 0x1078df1f0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df = unique_data.groupby(['movie_rating'])['box_office'].agg([np.mean, np.median, np.max, np.min, np.sum])
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4796/2195697296.py:2: FutureWarning: The provided callable <function median at 0x107e6a9d0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df = unique_data.groupby(['movie_rating'])['box_office'].agg([np.mean, np.median, np.max, np.min, np.sum])
# ...

# %%
x = pd.pivot_table(test_df, index="movie_rating")
x.sort_values("mean", ascending=False)
# Out:
#                      amax      amin          mean      median
# movie_rating
# PG-13         303001229.0  200000.0  7.690906e+07  43800000.0
# PG            261835892.0  252018.0  6.897532e+07  52277485.0
# R             368000000.0    8300.0  3.540829e+07  14037964.0
# G              18013938.0  598103.0  9.788142e+06  13592311.0
# NR              1626289.0     363.0  7.714906e+05    480926.0

# %%
# merge_data.to_csv('merge_data.csv')

# %%
unique_data
# Out:
#          id                                           synopsis movie_rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...            R
# 214      10  Some cast and crew from NBC's highly acclaimed...        PG-13
# 275      13  Stewart Kane, an Irishman living in the Austra...            R
# 509      23  A fictional film set in the alluring world of ...            R
# 696      25  From ancient Japan's most enduring tale, the e...        PG-13
# ...     ...                                                ...          ...
# 40102  1968  This holiday season, acclaimed filmmaker Camer...           PG
# 40273  1976  Embrace of the Serpent features the encounter,...           NR
# 40371  1980  A band of renegades on the run in outer space ...        PG-13
# 40502  1981  Money, Fame and the Knowledge of English. In I...           NR
# 40714  1996  Forget terrorists or hijackers -- there's a ha...            R
#
# ...
