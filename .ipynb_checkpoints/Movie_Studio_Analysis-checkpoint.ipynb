# %% [markdown]
# ## Overview ##

# %% [markdown]
# This project analyzes databases of movie to recommend the best movie studio to invest in.

# %% [markdown]
# ## Business Problem ##

# %% [markdown]
# Your company now sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of your company's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# ## Data Preparation ##

# %%
# import the necessary Python packages for analysis, computation, and visualization
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
#loading all the datasets
bom_movie_gross_data = pd.read_csv("Data/bom.movie_gross.csv.gz", compression="gzip")
rt_movie_info_data = pd.read_csv("Data/rt.movie_info.tsv.gz", compression="gzip", sep="\t", encoding="unicode_escape")
rt_reviews_data = pd.read_csv("Data/rt.reviews.tsv.gz", compression="gzip", sep="\t", encoding="unicode_escape")
tmdb_movies_data = pd.read_csv("Data/tmdb.movies.csv.gz", compression="gzip")
movie_budgets_data = pd.read_csv("Data/tn.movie_budgets.csv.gz", compression="gzip")

# %%
conn = sqlite3.connect("Data/im.db")
cur = conn.cursor()

# %%
pd.read_sql("""
    SELECT *
    FROM movie_basics
""", conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
 pd.read_sql("""
    SELECT *
    FROM movie_ratings;
""", conn)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# ##  Data Understanding ##

# %% [markdown]
# This data includes information from Rotten Tomatoes, Box Office Mojo, The Movie Database, The Numbers, and Internet Movie Database.

# %% [markdown]
# ## Who is our Audience ##
# Our first approach is determining our target audience for our movie studio. We will focus on analyzing two databases from Rotten Tomatoes for the movie rating and the Numbers and IMBD for the budget and worldwide gross. The budget and worldwide gross columns calculate the return on investment (ROI) for each film. Using the movie rating and ROI, to get a picture of which movie rating has the best ROI. From there, we will use the film rating system to come up with a general age demographic.

# %%
#Merging the two datasets from Rotten Tomatoes, focusing on the movie_ratings and box office. 
merge_data = rt_movie_info_data.merge(rt_reviews_data, how="inner", on="id")

# %%
#renaming the two rating columns 
merge_data = merge_data.rename(columns={'rating_x':'movie_rating', 'rating_y':'review_rating'})

# %%
#replace the letter grades into numeric values
merge_data["review_rating"] = merge_data["review_rating"].replace({'A+':'15/15',
                                                 'A':'14/15',
                                                 'A-':'13/15',
                                                 'B+':'12/15',
                                                 'B':'11/15',
                                                 'B-':'10/15',
                                                 'C+':'9/15',
                                                 'C':'8/15',
                                                 'C-':'7/15',
                                                 'D+':'6/15',
                                                 'D':'5/15',
                                                 'D-':'4/15',
                                                 'F+':'3/15',
                                                 'F':'2/15',
                                                 'F-':'1/15'})

# %%
#dropping the null values
merge_data.dropna(subset=['review_rating'], inplace=True)

# %%
#dropping these miscellaneous values 
merge_data = merge_data[merge_data['review_rating'] != 'T']
merge_data = merge_data[merge_data['review_rating'] != '1-5']
merge_data = merge_data[merge_data['review_rating'] != 'R']
merge_data = merge_data[merge_data['review_rating'] != 'N']
merge_data = merge_data[merge_data['review_rating'] != '3 1/2']

# %%
#strings values to fractions 
import string 
letters = string.ascii_uppercase

def to_decimal(fraction):
    if isinstance(fraction, str):
        try:
            a, b = fraction.split('/')
            x  = round((float(a) / float(b)), 2)
            return x
        except ValueError:
            return fraction
    else:
        return fraction
    
merge_data['review_rating'] = merge_data['review_rating'].map(lambda x: to_decimal(x) if x is not letters else x )

# %%
merge_data['review_rating'] = pd.to_numeric(merge_data['review_rating'])

# %%
#Assume the values greater than 1 are out of 10
def out_of_ten(ele):
    if ele > 1:
        return round(ele/10, 2)
    else:
        return ele
merge_data['review_rating'] = merge_data['review_rating'].map(out_of_ten)

# %%
#dropping the null values in the box_office column
merge_data.dropna(subset=['box_office'], inplace=True)

# %%
#removing the commas in the box_office column
merge_data['box_office'] = merge_data['box_office'].replace({',': ''}, regex=True)

# %%
#turning the values into numbers
merge_data['box_office'] = pd.to_numeric(merge_data['box_office'])

# %%
unique_data = merge_data.drop_duplicates(subset=['id'])

# %%
unique_data['theater_date'] = pd.to_datetime(unique_data['theater_date'])
unique_data['runtime'] = unique_data['runtime'].replace({'minutes': ''}, regex=True)
unique_data['runtime'] = pd.to_numeric(unique_data['runtime'])
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_3678/887571670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data['theater_date'] = pd.to_datetime(unique_data['theater_date'])
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_3678/887571670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data['runtime'] = unique_data['runtime'].replace({'minutes': ''}, regex=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_3678/887571670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data['runtime'] = pd.to_numeric(unique_data['runtime'])

# %%
#importing a merged dataset of The Number and IMDB 
roi_data = pd.read_csv("Data/budget_imdb.csv")
roi_data
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1   2009-12-18
# 1              1   2   2011-05-20
# 2              2   3   2019-06-07
# 3              3   4   2015-05-01
# 4              4   7   2018-04-27
# ...          ...  ..          ...
# 2870        2870  62   2014-12-31
# 2871        2871  68   2001-07-06
# 2872        2872  73   2012-01-13
# 2873        2873  78   2018-12-31
# 2874        2874  81   2015-09-29
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4                          Avengers: Infinity War          300000000
# ...                                           ...                ...
# 2870                         Stories of Our Lives              15000
# 2871                                         Cure              10000
# 2872                                    Newlyweds               9000
# 2873                                       Red 11               7000
# 2874                         A Plague So Pleasant               1400
#
#       domestic_gross  worldwide_gross   movie_id  \
# 0          760507625       2776345279  tt1775309
# 1          241063875       1045663875  tt1298650
# 2           42762350        149762350  tt6565702
# 3          459005868       1403013963  tt2395427
# 4          678815482       2048134200  tt4154756
# ...              ...              ...        ...
# 2870               0                0  tt3973612
# 2871           94596            94596  tt1872026
# 2872            4584             4584  tt1880418
# 2873               0                0  tt7837402
# 2874               0                0  tt2107644
#
#                                     primary_title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 2870                         Stories of Our Lives
# 2871                                         Cure
# 2872                                    Newlyweds
# 2873                                       Red 11
# 2874                         A Plague So Pleasant
#
#                                    original_title  start_year  \
# 0                                           Abatâ        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                    Dark Phoenix        2019
# 3                         Avengers: Age of Ultron        2015
# 4                          Avengers: Infinity War        2018
# ...                                           ...         ...
# 2870                         Stories of Our Lives        2014
# 2871                                         Cure        2011
# 2872                                    Newlyweds        2011
# 2873                                       Red 11        2019
# 2874                         A Plague So Pleasant        2013
#
#       runtime_minutes                              genres  averagerating  \
# 0                93.0                          ['Horror']            6.1
# 1               136.0  ['Action', 'Adventure', 'Fantasy']            6.6
# 2               113.0   ['Action', 'Adventure', 'Sci-Fi']            6.0
# 3               141.0   ['Action', 'Adventure', 'Sci-Fi']            7.3
# 4               149.0   ['Action', 'Adventure', 'Sci-Fi']            8.5
# ...               ...                                 ...            ...
# 2870             60.0                           ['Drama']            7.5
# 2871             93.0                           ['Drama']            4.9
# 2872             95.0                 ['Comedy', 'Drama']            6.4
# 2873             77.0    ['Horror', 'Sci-Fi', 'Thriller']            5.6
# 2874             76.0     ['Drama', 'Horror', 'Thriller']            5.4
#
#       numvotes       roi
# 0           43  6.532577
# 1       447624  2.546673
# 2        24451  0.427892
# 3       665594  4.243841
# 4       670926  6.827114
# ...        ...       ...
# 2870        85  0.000000
# 2871        11  9.459600
# 2872      1436  0.509333
# 2873        43  0.000000
# 2874        72  0.000000
#
# [2875 rows x 16 columns]

# %%
roi_data.dropna(subset=['release_date'])
roi_data['release_date'] = pd.to_datetime(roi_data['release_date'])

# %%
unique_data
# Out:
#          id                                           synopsis movie_rating  \
# 0         3  New York City, not-too-distant-future: Eric Pa...            R
# 318      10  Some cast and crew from NBC's highly acclaimed...        PG-13
# 426      13  Stewart Kane, an Irishman living in the Austra...            R
# 521      14  "Love Ranch" is a bittersweet love story that ...            R
# 726      23  A fictional film set in the alluring world of ...            R
# ...     ...                                                ...          ...
# 53567  1976  Embrace of the Serpent features the encounter,...           NR
# 53717  1980  A band of renegades on the run in outer space ...        PG-13
# 53887  1981  Money, Fame and the Knowledge of English. In I...           NR
# 53891  1986  Aki Kaurismaki's The Man Without a Past opens ...           PG
# 54175  1996  Forget terrorists or hijackers -- there's a ha...            R
#
#                                                   genre          director  \
# 0                     Drama|Science Fiction and Fantasy  David Cronenberg
# 318                                              Comedy       Jake Kasdan
# 426                                               Drama      Ray Lawrence
# 521                                               Drama   Taylor Hackford
# 726                                               Drama               NaN
# ...                                                 ...               ...
# 53567  Action and Adventure|Art House and International       Ciro Guerra
# 53717  Action and Adventure|Science Fiction and Fantasy       Joss Whedon
# 53887                                      Comedy|Drama      Gauri Shinde
# 53891          Art House and International|Comedy|Drama               NaN
# 54175  Action and Adventure|Horror|Mystery and Suspense               NaN
#
#                                      writer theater_date      dvd_date  \
# 0              David Cronenberg|Don DeLillo   2012-08-17   Jan 1, 2013
# 318                              Mike White   2002-01-11  Jun 18, 2002
# 426        Raymond Carver|Beatrix Christian   2006-04-27   Oct 2, 2007
# 521                           Mark Jacobson   2010-06-30   Nov 9, 2010
# 726                                     NaN   2013-12-20  Mar 18, 2014
# ...                                     ...          ...           ...
# 53567  Ciro Guerra|Jacques Toulemonde Vidal   2016-02-17  Jun 21, 2016
# 53717                           Joss Whedon   2005-09-30  Dec 20, 2005
# 53887                          Gauri Shinde   2012-10-05  Nov 20, 2012
# 53891                                   NaN   2002-08-30   Oct 7, 2003
# 54175                                   NaN   2006-08-18   Jan 2, 2007
#
#       currency  box_office  runtime                  studio  \
# 0            $      600000    108.0       Entertainment One
# 318          $    41032915     82.0      Paramount Pictures
# 426          $      224114    123.0  Sony Pictures Classics
# 521          $      134904    117.0                     NaN
# 726          $    99165609    129.0           Sony Pictures
# ...        ...         ...      ...                     ...
# 53567        $     1320005    123.0           Buffalo Films
# 53717        $    25335935    119.0      Universal Pictures
# 53887        $     1416189    129.0      Eros Entertainment
# 53891        $      794306     97.0                     NaN
# 54175        $    33886034    106.0         New Line Cinema
#
#                                                   review  review_rating  \
# 0      A distinctly gallows take on contemporary fina...           0.60
# 318    It won't stick with you forever, but you will ...           0.60
# 426    Subtle and understated, a meditation on morali...           0.88
# 521       A captivating film... [Full review in Spanish]           0.60
# 726    The movie is great. It is interesting without ...           0.80
# ...                                                  ...            ...
# 53567  The journey is definitely the destination in E...           0.88
# 53717  Thank you, [Joss], for creating this world, fo...           1.00
# 53887  A capable supporting cast and a fun cameo from...           0.60
# 53891                              ...dourly delightful.           0.88
# 54175  This is a good-looking film, and Jackson is ju...           0.73
#
#        fresh          critic  top_critic               publisher  \
# 0      fresh      PJ Nabarro           0         Patrick Nabarro
# 318    fresh             NaN           0                   Film4
# 426    fresh      Jeff Simon           0            Buffalo News
# 521    fresh     Laura Hiros           0                     NaN
# 726    fresh  Debbie Baldwin           0              Ladue News
# ...      ...             ...         ...                     ...
# 53567  fresh     Lisa Jensen           0   Good Times Santa Cruz
# 53717  fresh  Aaron Peterson           0  The Hollywood Outsider
# 53887  fresh    Anil Sinanan           1                Time Out
# 53891  fresh     Josh Larsen           0            LarsenOnFilm
# 54175  fresh     Joel Siegel           0    Good Morning America
#
#                      date
# 0       November 10, 2018
# 318       August 12, 2008
# 426         April 9, 2018
# 521        March 22, 2018
# 726      November 2, 2018
# ...                   ...
# 53567  September 11, 2017
# 53717    October 25, 2018
# 53887    October 23, 2017
# 53891        May 19, 2016
# 54175     January 4, 2018
#
# [299 rows x 19 columns]

# %%
#merging the roi_data with the unique_data 
merge_data2 = unique_data.merge(roi_data, how="inner", left_on=["theater_date", "runtime"], right_on=["release_date", "runtime_minutes"])
merge_data2
# Out:
#     id_x                                           synopsis movie_rating  \
# 0     14  "Love Ranch" is a bittersweet love story that ...            R
# 1     95  BLEED FOR THIS is the incredible true story of...            R
# 2    188  From the producers of Little Miss Sunshine - W...            R
# 3    251  In this adaptation of the novel "The Price of ...            R
# 4    300  Liz Gilbert had everything a modern woman is s...        PG-13
# 5    322  When her heart is stolen by a seductive strang...            R
# 6    482  Take out the trash, eat your broccoli-who need...           PG
# 7    482  Take out the trash, eat your broccoli-who need...           PG
# 8    610  American tourist Frank (Johnny Depp) meets a m...        PG-13
# 9    674  When 22 year-old drug dealer Chris (Hirsch) ha...            R
# 10   674  When 22 year-old drug dealer Chris (Hirsch) ha...            R
# 11   686  Set in a dystopic present where vigilant gargo...        PG-13
# 12   714  Newlywed couple Ted and Tami-Lynn want to have...            R
# 13   756  Based on a true story, U.S. Customs agent ROBE...            R
# 14   783  An all-star cast of action-movie icons headlin...            R
# 15   873  A sophisticated and moving comedy, THE EXTRA M...            R
# 16  1011  In Final Destination 5, Death is just as omnip...            R
# 17  1014  When a young American travels to the city of V...           PG
# 18  1083  Hollywood 1927. George Valentin (Jean Dujardin...        PG-13
# 19  1083  Hollywood 1927. George Valentin (Jean Dujardin...        PG-13
# 20  1084  Shy, sensitive April (Emma Roberts) is the cla...            R
# 21  1114  When four lifelong friends-Regina Hall, Queen ...            R
# 22  1169  From masters of horror Blumhouse Productions- ...        PG-13
# 23  1231  THE ROVER, David Michod's highly anticipated f...            R
# 24  1237  Sarah Jessica Parker, Greg Kinnear, Pierce Bro...        PG-13
# 25  1265  Beth (Diane Keaton) saves a bedraggled lost do...        PG-13
# 26  1334  Dating guru Matthew Taylor (Shemar Moore) fall...        PG-13
# 27  1362  BLACK OR WHITE is the story of a grandfather (...        PG-13
# 28  1398  A heartfelt tale of inspiration, hope and rede...           PG
# 29  1399  Imagine the end of the world. Now imagine some...            R
# 30  1561  The third installment of director Edgar Wright...            R
# 31  1574  Featuring an all-star comedy cast including Au...            R
# 32  1601  Rango is a sheltered chameleon living as an or...           PG
# 33  1639  In this darkly erotic drama from cult filmmake...           NR
# 34  1645  Texas brothers--Toby (Chris Pine), and Tanner ...            R
# 35  1646  Director Alexander Payne (Sideways, The Descen...            R
# 36  1785  The director of Mortal Kombat (1995) adapts an...            R
# 37  1890  A misplaced sausage and his savory friends emb...            R
# 38  1944  In the 3D action-comedy The Green Hornet, Brit...        PG-13
# 39  1981  Money, Fame and the Knowledge of English. In I...           NR
#
#                                                 genre  \
# 0                                               Drama
# 1                            Drama|Sports and Fitness
# 2                                        Comedy|Drama
# 3                                       Drama|Romance
# 4                                               Drama
# 5                                              Horror
# 6   Action and Adventure|Animation|Comedy|Science ...
# 7   Action and Adventure|Animation|Comedy|Science ...
# 8   Action and Adventure|Mystery and Suspense|Romance
# 9                         Comedy|Mystery and Suspense
# 10                        Comedy|Mystery and Suspense
# 11  Horror|Mystery and Suspense|Science Fiction an...
# 12                                             Comedy
# 13                                              Drama
# 14          Action and Adventure|Mystery and Suspense
# 15                                             Comedy
# 16                                             Horror
# 17                               Comedy|Drama|Romance
# 18                               Comedy|Drama|Romance
# 19                               Comedy|Drama|Romance
# 20                                              Drama
# 21                                       Comedy|Drama
# 22                                             Horror
# 23  Mystery and Suspense|Science Fiction and Fanta...
# 24                                             Comedy
# 25                                       Comedy|Drama
# 26                                     Comedy|Romance
# 27                                              Drama
# 28       Drama|Kids and Family|Faith and Spirituality
# 29                                       Drama|Horror
# 30                                             Comedy
# 31                                             Comedy
# 32     Action and Adventure|Animation|Kids and Family
# 33                  Art House and International|Drama
# 34                         Drama|Mystery and Suspense
# 35                                              Drama
# 36   Action and Adventure|Horror|Mystery and Suspense
# 37                                   Animation|Comedy
# 38  Action and Adventure|Comedy|Science Fiction an...
# 39                                       Comedy|Drama
#
#                                 director  \
# 0                        Taylor Hackford
# 1                            Ben Younger
# 2                        Colin Trevorrow
# 3                            Todd Haynes
# 4                            Ryan Murphy
# 5                     Guillermo del Toro
# 6                            Simon Wells
# 7                            Simon Wells
# 8       Florian Henckel von Donnersmarck
# 9                       William Friedkin
# 10                      William Friedkin
# 11                        Stuart Beattie
# 12                       Seth MacFarlane
# 13                           Brad Furman
# 14                    Sylvester Stallone
# 15  Robert Pulcini|Shari Springer Berman
# 16                          Steven Quale
# 17                           Gary Winick
# 18                   Michel Hazanavicius
# 19                   Michel Hazanavicius
# 20                           Gia Coppola
# 21                                   NaN
# 22                            David Gelb
# 23                                   NaN
# 24                       Douglas McGrath
# 25                       Lawrence Kasdan
# 26                        Youssef Delara
# 27                           Mike Binder
# 28          David Nixon|Patrick Doughtie
# 29                    Trey Edward Shults
# 30                          Edgar Wright
# 31                          Maggie Carey
# 32                        Gore Verbinski
# 33                        Jeanne Labrune
# 34                       David Mackenzie
# 35                       Alexander Payne
# 36                                   NaN
# 37            Conrad Vernon|Greg Tiernan
# 38                         Michel Gondry
# 39                          Gauri Shinde
#
#                                                writer theater_date  \
# 0                                       Mark Jacobson   2010-06-30
# 1                                         Ben Younger   2016-11-18
# 2                                      Derek Connolly   2012-06-08
# 3                                        Phyllis Nagy   2015-11-20
# 4                           Ryan Murphy|Jennifer Salt   2010-08-13
# 5    Guillermo del Toro|Matthew Robbins|Lucinda Coxon   2015-10-16
# 6                             Simon Wells|Wendy Wells   2011-03-11
# 7                             Simon Wells|Wendy Wells   2011-03-11
# 8   Florian Henckel von Donnersmarck|Christopher M...   2010-12-10
# 9                                         Tracy Letts   2012-07-27
# 10                                        Tracy Letts   2012-07-27
# 11                                     Stuart Beattie   2014-01-24
# 12         Seth MacFarlane|Alec Sulkin|Wellesley Wild   2015-06-26
# 13                                 Ellen Brown Furman   2016-07-13
# 14                   Dave Callaham|Sylvester Stallone   2010-08-13
# 15  Robert Pulcini|Jonathan Ames|Shari Springer Be...   2010-07-30
# 16                                     Eric Heisserer   2011-08-12
# 17                           Jose Rivera|Tim Sullivan   2010-05-14
# 18                                Michel Hazanavicius   2011-11-25
# 19                                Michel Hazanavicius   2011-11-25
# 20                                        Gia Coppola   2014-05-09
# 21                          Kenya Barris|Tracy Oliver   2017-07-21
# 22                          Luke Dawson|Jeremy Slater   2015-02-27
# 23                                                NaN   2014-06-13
# 24                                Aline Brosh McKenna   2011-09-16
# 25                         Lawrence Kasdan|Meg Kasdan   2012-04-20
# 26         Victor Teran|Youssef Delara|Staci Robinson   2016-12-09
# 27                                        Mike Binder   2015-01-30
# 28                                                NaN   2010-04-09
# 29                                 Trey Edward Shults   2017-06-09
# 30                            Edgar Wright|Simon Pegg   2013-08-23
# 31                                       Maggie Carey   2013-07-26
# 32                                         John Logan   2011-03-04
# 33                    Jeanne Labrune|Richard Debuisne   2011-08-26
# 34                                    Taylor Sheridan   2016-08-12
# 35                                         Bob Nelson   2013-11-15
# 36                                                NaN   2002-03-15
# 37  Kyle Hunter|Ariel Shaffir|Seth Rogen|Evan Gold...   2016-08-12
# 38                           Evan Goldberg|Seth Rogen   2011-01-14
# 39                                       Gauri Shinde   2012-10-05
#
#         dvd_date currency  box_office  ...  worldwide_gross   movie_id  \
# 0    Nov 9, 2010        $      134904  ...           146149  tt1125929
# 1   Feb 14, 2017        $     5051927  ...         32398681  tt4550098
# 2   Oct 30, 2012        $     4007792  ...          4422318  tt1862079
# 3   Mar 15, 2016        $     8518148  ...         42843521  tt2402927
# 4   Nov 23, 2010        $    80574010  ...        206598789  tt0879870
# 5    Feb 9, 2016        $    25957696  ...         74966854  tt2554274
# 6    Aug 9, 2011        $    21379315  ...         39549758  tt1305591
# 7    Aug 9, 2011        $    21379315  ...            39475  tt1314190
# 8   Mar 22, 2011        $    67631157  ...        278731369  tt1243957
# 9   Dec 21, 2012        $     1800000  ...         67130045  tt1298649
# 10  Dec 21, 2012        $     1800000  ...          4659110  tt1726669
# 11  May 13, 2014        $    15687400  ...         74575290  tt1418377
# 12  Dec 15, 2015        $    63883740  ...          3917679  tt2515030
# 13  Oct 11, 2016        $    15425870  ...         20718104  tt1355631
# 14  Nov 23, 2010        $   102981571  ...        268268174  tt1320253
# 15  Nov 16, 2010        $      453079  ...           492108  tt1361313
# 16  Dec 27, 2011        $    42500000  ...        155011165  tt1622979
# 17  Sep 14, 2010        $    53021560  ...         82148538  tt0892318
# 18  Jun 26, 2012        $    44667095  ...        128256712  tt1655442
# 19  Jun 26, 2012        $    44667095  ...        128256712  tt1825978
# 20   Sep 9, 2014        $      406235  ...          1156309  tt2479800
# 21  Oct 17, 2017        $   115088305  ...        140886353  tt3564472
# 22  Jun 16, 2015        $    20467547  ...         38359310  tt2918436
# 23  Sep 23, 2014        $      709133  ...          3180252  tt2345737
# 24   Jan 3, 2012        $     9500000  ...         24474463  tt1742650
# 25  Aug 28, 2012        $      793352  ...          1200346  tt1730687
# 26   Apr 4, 2017        $      320676  ...           421404  tt3253232
# 27   May 5, 2015        $    15504419  ...           288751  tt2704752
# 28  Aug 10, 2010        $     1121000  ...          3237452  tt1462054
# 29  Sep 12, 2017        $    13985117  ...         19720203  tt4695012
# 30  Nov 19, 2013        $    33408732  ...         47508505  tt1213663
# 31  Nov 19, 2013        $     3400000  ...          4128828  tt1758795
# 32  Jul 15, 2011        $   123188232  ...        245724600  tt1192628
# 33  Jan 17, 2012        $        8856  ...            29384  tt1470020
# 34  Nov 22, 2016        $    26973524  ...         37584304  tt2582782
# 35  Feb 25, 2014        $    11348612  ...         24761360  tt1821549
# 36  Jul 30, 2002        $    39532308  ...         78948765  tt1720297
# 37   Nov 8, 2016        $    97661826  ...        141344255  tt1700841
# 38   May 3, 2011        $    98000000  ...        229155503  tt0990407
# 39  Nov 20, 2012        $     1416189  ...          2721534  tt1181614
#
#                    primary_title                original_title start_year  \
# 0                     Love Ranch                    Love Ranch       2010
# 1              Nocturnal Animals             Nocturnal Animals       2016
# 2          Safety Not Guaranteed         Safety Not Guaranteed       2012
# 3                          Carol                         Carol       2015
# 4                  Eat Pray Love                 Eat Pray Love       2010
# 5                   Crimson Peak                  Crimson Peak       2015
# 6                Mars Needs Moms               Mars Needs Moms       2011
# 7                    3 Backyards                   3 Backyards       2010
# 8                    The Tourist                   The Tourist       2010
# 9                      The Watch                     The Watch       2012
# 10                    Killer Joe                    Killer Joe       2011
# 11               I, Frankenstein               I, Frankenstein       2014
# 12        Escobar: Paradise Lost        Escobar: Paradise Lost       2014
# 13               The Infiltrator               The Infiltrator       2016
# 14               The Expendables               The Expendables       2010
# 15                 The Extra Man                 The Extra Man       2010
# 16           Final Destination 5           Final Destination 5       2011
# 17             Letters to Juliet             Letters to Juliet       2010
# 18                    The Artist                    The Artist       2011
# 19                    The Artist                    The Artist       2011
# 20                     Palo Alto                     Palo Alto       2013
# 21                    Girls Trip                    Girls Trip       2017
# 22            The Lazarus Effect            The Lazarus Effect       2015
# 23                     The Rover                     The Rover       2014
# 24  I Don't Know How She Does It  I Don't Know How She Does It       2011
# 25             Darling Companion             Darling Companion       2012
# 26               The Bounce Back               The Bounce Back       2016
# 27              Above and Beyond              Above and Beyond       2014
# 28                Letters to God                Letters to God       2010
# 29             It Comes at Night             It Comes at Night       2017
# 30               The World's End               The World's End       2013
# 31                The To Do List                The To Do List       2013
# 32                         Rango                         Rango       2011
# 33               Redemption Road               Redemption Road       2010
# 34            Hell or High Water            Hell or High Water       2016
# 35                      Nebraska                      Nebraska       2013
# 36                      Showtime                 Yong xin tiao       2010
# 37                 Sausage Party                 Sausage Party       2016
# 38              The Green Hornet              The Green Hornet       2011
# 39             Wuthering Heights             Wuthering Heights       2011
#
#    runtime_minutes                                   genres averagerating  \
# 0            117.0         ['Biography', 'Comedy', 'Drama']           5.6
# 1            116.0                    ['Drama', 'Thriller']           7.5
# 2             86.0           ['Comedy', 'Drama', 'Romance']           7.0
# 3            118.0                     ['Drama', 'Romance']           7.2
# 4            133.0                     ['Drama', 'Romance']           5.8
# 5            119.0           ['Drama', 'Fantasy', 'Horror']           6.5
# 6             88.0     ['Adventure', 'Animation', 'Family']           5.4
# 7             88.0                                ['Drama']           5.0
# 8            103.0      ['Action', 'Adventure', 'Thriller']           6.0
# 9            102.0           ['Action', 'Comedy', 'Horror']           5.7
# 10           102.0           ['Crime', 'Drama', 'Thriller']           6.7
# 11            92.0          ['Action', 'Fantasy', 'Horror']           5.1
# 12           120.0            ['Crime', 'Drama', 'History']           6.5
# 13           127.0          ['Biography', 'Crime', 'Drama']           7.0
# 14           103.0      ['Action', 'Adventure', 'Thriller']           6.5
# 15           108.0                               ['Comedy']           5.9
# 16            92.0                               ['Horror']           5.9
# 17           105.0         ['Adventure', 'Comedy', 'Drama']           6.6
# 18           100.0           ['Comedy', 'Drama', 'Romance']           7.9
# 19           100.0                             ['Thriller']           6.8
# 20           100.0                                ['Drama']           6.2
# 21           122.0                      ['Comedy', 'Drama']           6.2
# 22            83.0          ['Horror', 'Mystery', 'Sci-Fi']           5.2
# 23           103.0             ['Action', 'Crime', 'Drama']           6.4
# 24            89.0                    ['Comedy', 'Romance']           4.9
# 25           103.0           ['Comedy', 'Drama', 'Romance']           5.1
# 26           104.0                    ['Comedy', 'Romance']           5.0
# 27            90.0  ['Adventure', 'Documentary', 'History']           7.7
# 28           110.0                      ['Drama', 'Family']           6.3
# 29            91.0                    ['Horror', 'Mystery']           6.2
# 30           109.0           ['Action', 'Comedy', 'Sci-Fi']           7.0
# 31           104.0                    ['Comedy', 'Romance']           5.8
# 32           107.0     ['Adventure', 'Animation', 'Comedy']           7.2
# 33            95.0                                ['Drama']           5.8
# 34           102.0             ['Action', 'Crime', 'Drama']           7.6
# 35           115.0         ['Adventure', 'Comedy', 'Drama']           7.7
# 36           100.0          ['Drama', 'Fantasy', 'Musical']           4.2
# 37            89.0     ['Adventure', 'Animation', 'Comedy']           6.2
# 38           119.0            ['Action', 'Comedy', 'Crime']           5.8
# 39           129.0                     ['Drama', 'Romance']           6.1
#
#    numvotes       roi
# 0      2742  0.005846
# 1    205240  1.439941
# 2    111907  5.896424
# 3    100680  3.630807
# 4     77709  3.443313
# 5    119287  1.363034
# 6     19823  0.263665
# 7       611  0.131583
# 8    206714  2.787314
# 9    115757  1.220546
# 10    67842  0.465911
# 11    74910  1.147312
# 12    19419  0.230452
# 13    61547  0.436171
# 14   307897  3.271563
# 15     4580  0.070301
# 16    98061  3.875279
# 17    86137  2.738285
# 18   217184  8.016044
# 19        6  8.016044
# 20    25402  1.156309
# 21    29321  5.031655
# 22    37675  7.671862
# 23    40576  0.374147
# 24    18552  1.019769
# 25     3085  0.100029
# 26      492  0.140468
# 27      506  0.222116
# 28     4443  1.079151
# 29    69039  3.944041
# 30   235308  2.375425
# 31    34524  2.752552
# 32   215761  1.820182
# 33      479  0.012776
# 34   176469  3.132025
# 35   105304  2.063447
# 36       20  0.928809
# 37   159111  7.439171
# 38   148622  2.083232
# 39     8549  0.340192
#
# [40 rows x 35 columns]

# %%
sns.boxplot(data=merge_data2, x=merge_data2["movie_rating"], 
            y=merge_data2["roi"]).set_title("ROI for Movie Ratings")
# plt.savefig("boxplot_review_movie.png")
;
# Out:
# ''

# %%
merge_data2['movie_rating'].value_counts()
# Out:
# movie_rating
# R        22
# PG-13    11
# PG        5
# NR        2
# Name: count, dtype: int64

# %%
#performing a one tail t test 
roi_mean = roi_data['roi'].mean()
pg13_sample = merge_data2[merge_data2['movie_rating'] == 'PG-13']['roi']

# %%
stats.ttest_1samp(a = pg13_sample, popmean = roi_mean, alternative="greater") #dont have enough samples 
#failed to reject the null hypothesis since the p-value is greater than the alpha value of 0.05
# Out:
# TtestResult(statistic=-0.9838700725150024, pvalue=0.8258077164717776, df=10)

# %%
pg_sample = merge_data2[merge_data2['movie_rating'] == 'PG']['roi']
stats.ttest_1samp(a = pg_sample, popmean = roi_mean, alternative="less")
#Reject the null hypothesis since the p-value is less than the alpha value of 0.05
# Out:
# TtestResult(statistic=-5.935485034831267, pvalue=0.0020196605043971833, df=4)

# %%
r_sample = merge_data2[merge_data2['movie_rating'] == 'R']['roi']
stats.ttest_1samp(a = r_sample, popmean = roi_mean, alternative="greater")
# Out:
# TtestResult(statistic=-4.124152139133418, pvalue=0.9997585620911366, df=21)

# %%
# merge_data2.to_csv('merge_data2.csv')

# %% [markdown]
# ## The Numbers ROI ##

# %%
movie_budgets_data.domestic_gross = movie_budgets_data.domestic_gross.map(lambda x: int(x.strip('$').replace(',', '')))
movie_budgets_data.worldwide_gross = movie_budgets_data.worldwide_gross.map(lambda x: int(x.strip('$').replace(',', '')))
movie_budgets_data.production_budget = movie_budgets_data.production_budget.map(lambda x: int(x.strip('$').replace(',', '')))

# %%
movie_budgets_data[movie_budgets_data.domestic_gross < movie_budgets_data.worldwide_gross]
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5759  60   Jun 2, 2006                              The Puffy Chair
# 5773  74  Feb 26, 1993                                  El Mariachi
# 5774  75   Oct 8, 2004                                       Primer
# 5775  76  May 26, 2006                                       Cavite
# 5778  79   Apr 2, 1999                                    Following
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5759              15000          194523           195254
# 5773               7000         2040920          2041928
# 5774               7000          424760           841926
# 5775               7000           70071            71644
# 5778               6000           48482           240495
#
# [4163 rows x 6 columns]

# %% [markdown]
# ## Conclusion ##

# %% [markdown]
# We can see from our boxplot above that PG-13 performs the best in the box office compared to the other ratings. Thus, we can conclude our target demographic is anyone ages of 13 and up.
